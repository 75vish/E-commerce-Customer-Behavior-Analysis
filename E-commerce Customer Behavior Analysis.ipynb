# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ecommerce_customer_data_custom_ratios.csv")
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.shape
# Out:
# (250000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB

# %%
df.describe()
# Out:
#         Customer ID  Product Price       Quantity  Total Purchase Amount  \
# count  250000.00000  250000.000000  250000.000000          250000.000000
# mean    25004.03624     254.659512       2.998896            2725.370732
# std     14428.27959     141.568577       1.414694            1442.933565
# min         1.00000      10.000000       1.000000             100.000000
# 25%     12497.75000     132.000000       2.000000            1477.000000
# 50%     25018.00000     255.000000       3.000000            2724.000000
# 75%     37506.00000     377.000000       4.000000            3974.000000
# max     50000.00000     500.000000       5.000000            5350.000000
#
#         Customer Age        Returns            Age          Churn
# count  250000.000000  202404.000000  250000.000000  250000.000000
# mean       43.940528       0.497861      43.940528       0.199496
# std        15.350246       0.499997      15.350246       0.399622
# ...

# %%
df.isnull()
# Out:
#         Customer ID  Purchase Date  Product Category  Product Price  Quantity  \
# 0             False          False             False          False     False
# 1             False          False             False          False     False
# 2             False          False             False          False     False
# 3             False          False             False          False     False
# 4             False          False             False          False     False
# ...             ...            ...               ...            ...       ...
# 249995        False          False             False          False     False
# 249996        False          False             False          False     False
# 249997        False          False             False          False     False
# 249998        False          False             False          False     False
# 249999        False          False             False          False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                  0
# Purchase Date                0
# Product Category             0
# Product Price                0
# Quantity                     0
# Total Purchase Amount        0
# Payment Method               0
# Customer Age                 0
# Returns                  47596
# Customer Name                0
# Age                          0
# Gender                       0
# Churn                        0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Customer ID              0
# Purchase Date            0
# Product Category         0
# Product Price            0
# Quantity                 0
# Total Purchase Amount    0
# Payment Method           0
# Customer Age             0
# Returns                  0
# Customer Name            0
# Age                      0
# Gender                   0
# Churn                    0
# dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    101798
# Male      100606
# Name: count, dtype: int64

# %%
sns.countplot(x="Gender",data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
df.rename(columns={"Customer ID":"Customer_ID","Purchase Date":"Purchase_Date","Product Category":"Product_Category","Product Price":"Product_Price","Total Purchase Amount":"Total_Purchase_Amount","Payment Method":"Payment_Method","Customer Age":"Customer_Age","Customer Name":"Customer_Name"},inplace=True)
df.head()
# Out:
#    Customer_ID        Purchase_Date Product_Category  Product_Price  Quantity  \
# 0        46251  2020-09-08 09:38:32      Electronics             12         3
# 1        46251  2022-03-05 12:56:35             Home            468         4
# 2        46251  2022-05-23 18:18:01             Home            288         2
# 3        46251  2020-11-12 13:13:29         Clothing            196         1
# 4        13593  2020-11-27 17:55:11             Home            449         1
#
#    Total_Purchase_Amount Payment_Method  Customer_Age  Returns  \
# 0                    740    Credit Card            37      0.0
# 1                   2739         PayPal            37      0.0
# 2                   3196         PayPal            37      0.0
# 3                   3509         PayPal            37      0.0
# 4                   3452    Credit Card            49      0.0
#
#          Customer_Name  Age  Gender  Churn
# 0  Christine Hernandez   37    Male      0
# ...

# %%
df.Payment_Method.value_counts()
# Out:
# Payment_Method
# Credit Card    81394
# PayPal         60603
# Cash           40406
# Crypto         20001
# Name: count, dtype: int64

# %%
sns.countplot(x="Payment_Method",data=df)
# Out:
# <Axes: xlabel='Payment_Method', ylabel='count'>

# %%
total_purchase=df.groupby("Gender")["Total_Purchase_Amount"].sum()
total_purchase
# Out:
# Gender
# Female    277606922
# Male      273970455
# Name: Total_Purchase_Amount, dtype: int64

# %%
df.Product_Category.value_counts()
# Out:
# Product_Category
# Clothing       60729
# Books          60595
# Electronics    40657
# Home           40423
# Name: count, dtype: int64

# %%
sns.countplot(x="Product_Category",data=df)
# Out:
# <Axes: xlabel='Product_Category', ylabel='count'>

# %%
males=df[df["Gender"]=="Male"]
females=df[df["Gender"]=="Female"]

# %%
category_counts1 = males['Product_Category'].value_counts()
plt.pie(category_counts1, labels=category_counts1.index, autopct='%1.1f%%', startangle=90)
plt.title("Male Purchasing History")
plt.show()

# %%
category_counts2 = females['Product_Category'].value_counts()
plt.pie(category_counts2, labels=category_counts2.index, autopct='%1.1f%%', startangle=90)
plt.title("Female Purchasing History")
plt.show()

# %%
sns.histplot(x="Customer_Age",data=df)
# Out:
# <Axes: xlabel='Customer_Age', ylabel='Count'>

# %%
return1=df[df["Returns"]==1.0]
cat_ret1=return1["Product_Category"].value_counts()

# %%
plt.pie(cat_ret1, labels=cat_ret1.index, autopct='%1.1f%%', startangle=90)
plt.title("Pie Chart showing Returns of each category")
plt.show()

# %%
males.Churn.value_counts()
# Out:
# Churn
# 0    80166
# 1    20440
# Name: count, dtype: int64

# %%
females.Churn.value_counts()
# Out:
# Churn
# 0    81874
# 1    19924
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1,2,figsize=(12, 6))
sns.countplot(x="Churn",data=males,ax=axes[0])
axes[0].set_title("Churn Distribution in Males")
sns.countplot(x="Churn",data=females,ax=axes[1])
axes[1].set_title("Churn Distribution in Females")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Customer_Age", y="Churn", data=df, estimator="mean", err_style=None, marker="o", color="b")
plt.title("Churn Status by Age")
plt.xlabel("Age")
plt.ylabel("Churn Rate (Mean)")
plt.yticks([0, 1], ["Retained", "Churned"])
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['Purchase_Date'] = pd.to_datetime(df['Purchase_Date'])
df["New_Date"] = df["Purchase_Date"].dt.to_period('Y')
monthly_revenue = df.groupby("New_Date")['Product_Price'].sum()
plt.figure(figsize=(10, 6))
monthly_revenue.plot(kind='bar', color='skyblue')
plt.title('Yearly Revenue')
plt.xlabel('Year')
plt.ylabel('Revenue ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df["Purchase_Date"] = pd.to_datetime(df["Purchase_Date"])
df["Year"] = df["Purchase_Date"].dt.year
df["Month"] = df["Purchase_Date"].dt.month
monthly_revenue = df.groupby(["Year", "Month"])["Product_Price"].sum().reset_index()
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 10), sharex=True)
for ax, year in zip(axes, monthly_revenue["Year"].unique()):
    data_year = monthly_revenue[monthly_revenue["Year"] == year]
    ax.stackplot(data_year["Month"], data_year["Product_Price"], labels=['Revenue'], alpha=0.7)
    ax.set_title(f'Monthly Revenue for Year {year}')
    ax.set_xlabel('Month')
    ax.set_ylabel('Revenue ($)')
    ax.set_xticks(range(1, 13))
    ax.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion
# - The digital marketplace has a majority of female shoppers
# - The total amount of purchases done by females is more than that of males
# - The most common form of payment is credit card
# - The most purchased product is clothing followed by books, electronics and home
# - It could be seen that books was a popular choice of purchase among males while among females the popular choice of purchase was clothing
# - The most returned item were books
# - Females retained their relationship with the marketplace more than males
# - It could also be seen that people in their 40s were more prone to not retain their relationship with the marketplace
# - The marketplace earned the most revenue in the year 2020
